# %%
# %%bash
# pip install music21

# %%
from music21 import *
c_middle = note.Note("C4")
print(c_middle.name)
print(c_middle.octave)
print(c_middle.frequency)
# Out:
# C
# 4
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-b2a098b24870> in <module>()
#       3 print(c_middle.name)
#       4 print(c_middle.octave)
# ----> 5 print(c_middle.frequency)
#
# AttributeError: 'Note' object has no attribute 'frequency'

# %%
d = note.Note("D4")
e = note.Note("E4")
f = note.Note("F4")
g = note.Note("G4")
a = note.Note("A5")
b = note.Note("B5")
c = note.Note("C5")

# %%
converter.parse("tinynotation: 4/4 c_middle4 d4 e4 f4 g4 a4 b4 c4").show()

# %%
bach = corpus.parse('bach/bwv65.2.xml')
bach.show()

# %%
bach.measures(0,2).show()

# %%
paths = corpus.getComposer(u'ryansmammoth')

# %%
print(paths)
# Out:
# [PosixPath('/Users/willingc/code/music21/music21/corpus/ryansMammoth/42dHighlandRegimentStrathspey.abc'), PosixPath('/Users/willingc/code/music21/music21/corpus/ryansMammoth/7thRegimentReel.abc'), PosixPath('/Users/willingc/code/music21/music21/corpus/ryansMammoth/AWillieWeHaveMissdYouStrathspey.abc'), PosixPath('/Users/willingc/code/music21/music21/corpus/ryansMammoth/AbithaMugginsFavoriteReel.abc'), PosixPath('/Users/willingc/code/music21/music21/corpus/ryansMammoth/AcaciaReel.abc'), PosixPath('/Users/willingc/code/music21/music21/corpus/ryansMammoth/AcrobatsHornpipe.abc'), PosixPath('/Users/willingc/code/music21/music21/corpus/ryansMammoth/AdmiralsHornpipe.abc'), PosixPath('/Users/willingc/code/music21/music21/corpus/ryansMammoth/AfterTheHareReel.abc'), PosixPath('/Users/willingc/code/music21/music21/corpus/ryansMammoth/AlbemarleHornpipe.abc'), PosixPath('/Users/willingc/code/music21/music21/corpus/ryansMammoth/AldridgesHornpipe.abc'), PosixPath('/Users/willingc/code/music21/music
# ...

# %%
yah = corpus.parse('ryansMammoth/YoungAmericaHornpipe.abc')
yah.show('musicxml')

# %%
myEnv = environment.UserSettings()
myEnv.getSettingsPath()
# Out:
# PosixPath('/Users/willingc/.music21rc')

# %%
from music21.braille import translate
samplePart = converter.parse("tinynotation: 3/4 C4 D16 E F G# r4 e2.")
samplePart.show()
